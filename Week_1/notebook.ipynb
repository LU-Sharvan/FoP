# %%
base = 10
increment = 7
exponent = -5
offset = 3

print(base, increment, exponent, offset)
# Out:
# 10 7 -5 3

# %%
calc1 = increment + base
print(calc1)
# Out:
# 17

# %%
calc2 = base ** exponent
print(calc2)
# Out:
# 1e-05

# %%
calc3 = abs(calc2 - calc1 + offset)
print(calc3)
# Out:
# 13.99999
