# %%
base = 10
increment = 7
exponent = -5
offset = 3

base, offset, increment, exponent
# Out:
# (10, 3, 7, -5)

# %%
calc1 = increment + base
calc1
# Out:
# 17

# %%
calc2 = base ** exponent
calc2
# Out:
# 1e-05

# %%
calc3 = abs(calc2 - calc1 + offset)
calc3
# Out:
# 13.99999
